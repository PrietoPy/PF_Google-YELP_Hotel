# %%
import apache_beam as beam
import json
import polars as pl
import googlemaps
from apache_beam.runners.interactive.display import pipeline_graph
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner

# %%
archivo_entrada = './raw-data/1.json'
archivo_salida = './clean-data/x.parquet'

# %%
# Configurar la API Key de Google Maps
with open('./APK/APK.txt', 'r') as file:
    api_key = file.read().strip()

gmaps = googlemaps.Client(key=api_key)

# %%
# Función para cargar un archivo JSON y convertirlo en un DataFrame de Pandas
def cargar_archivo_json(archivo):
    data_list=[]
    with open(archivo, 'r') as file:
        for line in file:
            # Cargar cada objeto JSON por separado
            data = json.loads(line)
            data_list.append(data)

    # Ahora data_list es una lista que contiene todos los objetos JSON del archivo
    df = pl.DataFrame(data_list)
    return df

# %%
# Función para realizar transformaciones en el DataFrame de Pandas
def aplicar_transformaciones(dft):
    dft = dft.drop(['address', 'description', 'price', 'hours', 'MISC', 'state', 'relative_results'])
    dft = dft.explode('category')
    dft = dft.filter(dft['category'].str.contains(f'(?i)hotel'))
    dft = dft.unique(subset=['gmap_id'], keep='first')
    return dft

# %%
# Definir la función para obtener city y country a partir de coordenadas
def obtener_geo(df2):
    counties, cities, states, countries, = [], [], [], []

    for lat, lon in zip(df2['latitude'], df2['longitude']):
        resultado = gmaps.reverse_geocode((lat, lon))
        county, city, state, country = None, None, None, None

        if resultado:
            for component in resultado[0]['address_components']:
                if 'locality' in component['types'] and not city:
                    city = component['long_name']

                elif 'administrative_area_level_2' in component['types'] and not county:
                    county = component['long_name']

                elif 'administrative_area_level_1' in component['types'] and not state:
                    state = component['long_name']

                elif 'country' in component['types'] and not country:
                    country = component['long_name']
                elif city and county and state and country:
                  break

        counties.append(county)
        cities.append(city)
        states.append(state)
        countries.append(country)

    counties, cities, states, countries = pl.Series(counties), pl.Series(cities), pl.Series(states), pl.Series(countries)
    df2 = df2.with_columns(
    County=counties,
    City=cities,
    State=states,
    Country=countries)
    return df2

# %%
with beam.Pipeline() as pipeline:
    # Carga el archivo json como una PCollection de Polars DataFrames
    datos_pcollection = (
        pipeline
        | 'Cargar archivo json' >> beam.Create([archivo_entrada])
        | 'Convertir a DataFrame de Polars' >> beam.Map(cargar_archivo_json)
    )

    # Aplica transformaciones utilizando Polars
    datos_transformados_pcollection = (
        datos_pcollection
        | 'Aplicar transformaciones' >> beam.Map(aplicar_transformaciones)
    )
    # Aplica transformaciones utilizando Polars
    #datos_geograficos_pcollection = (
    #    datos_transformados_pcollection
    #    | 'Obtener datos geograficos' >> beam.Map(obtener_geo)
    #)
    # guarda el resultado
    datos_transformados_pcollection | 'Guardar datos transformados' >> beam.Map(lambda df: df.write_parquet(archivo_salida))
# Out:
# ERROR:apache_beam.runners.common:could not create a new DataFrame: series "Service options" has length 2 while series "Accessibility" has length 1 [while running '[10]: Convertir a DataFrame de Polars']
# Traceback (most recent call last):
#   File "apache_beam\runners\common.py", line 1435, in apache_beam.runners.common.DoFnRunner.process
#   File "apache_beam\runners\common.py", line 637, in apache_beam.runners.common.SimpleInvoker.invoke_process
#   File "c:\Program Files\Python311\Lib\site-packages\apache_beam\transforms\core.py", line 1963, in <lambda>
#     wrapper = lambda x: [fn(x)]
#                          ^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_12480\3786972356.py", line 6, in cargar_archivo_json
#     df = pl.DataFrame(x)
#          ^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Roaming\Python\Python311\site-packages\polars\dataframe\frame.py", line 369, in __init__
#     self._df = dict_to_pydf(
#                ^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py", line 990, in dict_to_pydf
#     for s in _expand_dict_scalars(
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py", line 890, in _expand_dict_scalars
#     updated_data[name] = pl.DataFrame(val).to_struct(name)
#                          ^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Roaming\Python\Python311\site-packages\polars\dataframe\frame.py", line 369, in __init__
#     self._df = dict_to_pydf(
#                ^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py", line 996, in dict_to_pydf
#     pydf = PyDataFrame(data_series)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# polars.exceptions.ShapeError: could not create a new DataFrame: series "Service options" has length 2 while series "Accessibility" has length 1
# <class 'str'>
# {"name": "Porter Pharmacy", "address": "Porter Pharmacy, 129 N Second St, Cochran, GA 31014", "gmap_id": "0x88f16e41928ff687:0x883dad4fd048e8f8", "description": null, "latitude": 32.3883, "longitude": -83.3571, "category": ["Pharmacy"], "avg_rating": 4.9, "num_of_reviews": 16, "price": null, "hours": [["Friday", "8AM\u20136PM"], ["Saturday", "8AM\u201312PM"], ["Sunday", "Closed"], ["Monday", "8AM\u20136PM"], ["Tuesday", "8AM\u20136PM"], ["Wednesday", "8AM\u201312PM"], ["Thursday", "8AM\u20136PM"]], "MISC": {"Service options": ["In-store shopping", "Same-day delivery"], "Health & safety": ["Mask required", "Staff required to disinfect surfaces between visits"], "Accessibility": ["Wheelchair accessible entrance"], "Planning": ["Quick visit"]}, "state": "Open \u22c5 Closes 6PM", "relative_results": ["0x88f16e41929435cf:0x5b2532a2885e9ef6", "0x88f16c32716531c1:0x5f19bdaa5044e4fa", "0x88f16e6e3f4a21df:0xcf495da9bb4d89ea"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us"}
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1435, in apache_beam.runners.common.DoFnRunner.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:637, in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\transforms\core.py:1963, in Map.<locals>.<lambda>(x)
#    1962 else:
# -> 1963   wrapper = lambda x: [fn(x)]
#    1965 label = 'Map(%s)' % ptransform.label_from_callable(fn)
#
# Cell In[9], line 6, in cargar_archivo_json(archivo)
#       5 x = json.loads(archivo)
# ----> 6 df = pl.DataFrame(x)
#       7 return df
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\dataframe\frame.py:369, in DataFrame.__init__(self, data, schema, schema_overrides, orient, infer_schema_length, nan_to_null)
#     368 elif isinstance(data, dict):
# --> 369     self._df = dict_to_pydf(
#     370         data,
#     371         schema=schema,
#     372         schema_overrides=schema_overrides,
#     373         nan_to_null=nan_to_null,
#     374     )
#     376 elif isinstance(data, (list, tuple, Sequence)):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py:990, in dict_to_pydf(data, schema, schema_overrides, nan_to_null)
#     987 else:
#     988     data_series = [
#     989         s._s
# --> 990         for s in _expand_dict_scalars(
#     991             data, schema_overrides=schema_overrides, nan_to_null=nan_to_null
#     992         ).values()
#     993     ]
#     995 data_series = _handle_columns_arg(data_series, columns=column_names, from_dict=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py:890, in _expand_dict_scalars(data, schema_overrides, order, nan_to_null)
#     889 if isinstance(val, dict) and dtype != Struct:
# --> 890     updated_data[name] = pl.DataFrame(val).to_struct(name)
#     892 elif isinstance(val, pl.Series):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\dataframe\frame.py:369, in DataFrame.__init__(self, data, schema, schema_overrides, orient, infer_schema_length, nan_to_null)
#     368 elif isinstance(data, dict):
# --> 369     self._df = dict_to_pydf(
#     370         data,
#     371         schema=schema,
#     372         schema_overrides=schema_overrides,
#     373         nan_to_null=nan_to_null,
#     374     )
#     376 elif isinstance(data, (list, tuple, Sequence)):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py:996, in dict_to_pydf(data, schema, schema_overrides, nan_to_null)
#     995 data_series = _handle_columns_arg(data_series, columns=column_names, from_dict=True)
# --> 996 pydf = PyDataFrame(data_series)
#     998 if schema_overrides and pydf.dtypes() != list(schema_overrides.values()):
#
# ShapeError: could not create a new DataFrame: series "Service options" has length 2 while series "Accessibility" has length 1
#
# During handling of the above exception, another exception occurred:
#
# ShapeError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with beam.Pipeline() as pipeline:
#       2     # Carga el archivo json como una PCollection de Polars DataFrames
#       3     datos_pcollection = (
#       4         pipeline
#       5         | 'Cargar archivo json' >> beam.io.ReadFromText(archivo_entrada)
#       6         | 'Convertir a DataFrame de Polars' >> beam.Map(cargar_archivo_json)
#       7     )
#       9     # Aplica transformaciones utilizando Polars
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\pipeline.py:612, in Pipeline.__exit__(self, exc_type, exc_val, exc_tb)
#     610 try:
#     611   if not exc_type:
# --> 612     self.result = self.run()
#     613     self.result.wait_until_finish()
#     614 finally:
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\pipeline.py:586, in Pipeline.run(self, test_runner_api)
#     584     finally:
#     585       shutil.rmtree(tmpdir)
# --> 586   return self.runner.run_pipeline(self, self._options)
#     587 finally:
#     588   if not is_in_ipython():
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\direct\direct_runner.py:128, in SwitchingDirectRunner.run_pipeline(self, pipeline, options)
#     125 else:
#     126   runner = BundleBasedDirectRunner()
# --> 128 return runner.run_pipeline(pipeline, options)
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py:202, in FnApiRunner.run_pipeline(self, pipeline, options)
#     191   _LOGGER.warning(
#     192       'If direct_num_workers is not equal to 1, direct_running_mode '
#     193       'should be `multi_processing` or `multi_threading` instead of '
#    (...)
#     196       self._num_workers,
#     197       running_mode)
#     199 self._profiler_factory = Profile.factory_from_options(
#     200     options.view_as(pipeline_options.ProfilingOptions))
# --> 202 self._latest_run_result = self.run_via_runner_api(
#     203     pipeline.to_runner_api(default_environment=self._default_environment),
#     204     options)
#     205 return self._latest_run_result
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py:224, in FnApiRunner.run_via_runner_api(self, pipeline_proto, options)
#     222   pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     223 stage_context, stages = self.create_stages(pipeline_proto)
# --> 224 return self.run_stages(stage_context, stages)
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py:466, in FnApiRunner.run_stages(self, stage_context, stages)
#     463 assert consuming_stage_name == bundle_context_manager.stage.name
#     465 bundle_counter += 1
# --> 466 bundle_results = self._execute_bundle(
#     467     runner_execution_context, bundle_context_manager, bundle_input)
#     469 if consuming_stage_name in monitoring_infos_by_stage:
#     470   monitoring_infos_by_stage[
#     471       consuming_stage_name] = consolidate_monitoring_infos(
#     472           itertools.chain(
#     473               bundle_results.process_bundle.monitoring_infos,
#     474               monitoring_infos_by_stage[consuming_stage_name]))
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py:794, in FnApiRunner._execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     789 # We create the bundle manager here, as it can be reused for bundles of
#     790 # the same stage, but it may have to be created by-bundle later on.
#     791 bundle_manager = self._get_bundle_manager(bundle_context_manager)
#     793 last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 794     self._run_bundle(
#     795         runner_execution_context,
#     796         bundle_context_manager,
#     797         bundle_input,
#     798         bundle_context_manager.stage_data_outputs,
#     799         bundle_context_manager.stage_timer_outputs,
#     800         bundle_manager))
#     802 for pc_name, watermark in watermark_updates.items():
#     803   _BUNDLE_LOGGER.debug('Update: %s %s', pc_name, watermark)
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py:1031, in FnApiRunner._run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#    1022 input_timers = bundle_input.timers
#    1023 self._run_bundle_multiple_times_for_testing(
#    1024     runner_execution_context,
#    1025     bundle_manager,
#    (...)
#    1028     input_timers,
#    1029     expected_timer_output)
# -> 1031 result, splits = bundle_manager.process_bundle(
#    1032     data_input, data_output, input_timers, expected_timer_output)
#    1033 # Now we collect all the deferred inputs remaining from bundle execution.
#    1034 # Deferred inputs can be:
#    1035 # - timers
#    1036 # - SDK-initiated deferred applications of root elements
#    1037 # - Runner-initiated deferred applications of root elements
#    1038 deferred_inputs = {}  # type: Dict[str, execution.PartitionableBuffer]
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py:1367, in BundleManager.process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1360 # Actually start the bundle.
#    1361 process_bundle_req = beam_fn_api_pb2.InstructionRequest(
#    1362     instruction_id=process_bundle_id,
#    1363     process_bundle=beam_fn_api_pb2.ProcessBundleRequest(
#    1364         process_bundle_descriptor_id=self.bundle_context_manager.
#    1365         process_bundle_descriptor.id,
#    1366         cache_tokens=[next(self._cache_token_generator)]))
# -> 1367 result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1369 split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#    1370 with ProgressRequester(self._worker_handler,
#    1371                        process_bundle_id,
#    1372                        self._progress_frequency):
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py:384, in EmbeddedWorkerHandler.push(self, request)
#     382   self._uid_counter += 1
#     383   request.instruction_id = 'control_%s' % self._uid_counter
# --> 384 response = self.worker.do_instruction(request)
#     385 return ControlFuture(request.instruction_id, response)
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\sdk_worker.py:650, in SdkWorker.do_instruction(self, request)
#     647 request_type = request.WhichOneof('request')
#     648 if request_type:
#     649   # E.g. if register is set, this will call self.register(request.register))
# --> 650   return getattr(self, request_type)(
#     651       getattr(request, request_type), request.instruction_id)
#     652 else:
#     653   raise NotImplementedError
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\sdk_worker.py:688, in SdkWorker.process_bundle(self, request, instruction_id)
#     684 with bundle_processor.state_handler.process_instruction_id(
#     685     instruction_id, request.cache_tokens):
#     686   with self.maybe_profile(instruction_id):
#     687     delayed_applications, requests_finalization = (
# --> 688         bundle_processor.process_bundle(instruction_id))
#     689     monitoring_infos = bundle_processor.monitoring_infos()
#     690     response = beam_fn_api_pb2.InstructionResponse(
#     691         instruction_id=instruction_id,
#     692         process_bundle=beam_fn_api_pb2.ProcessBundleResponse(
#    (...)
#     698             },
#     699             requires_finalization=requests_finalization))
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\bundle_processor.py:1113, in BundleProcessor.process_bundle(self, instruction_id)
#    1110         self.ops[element.transform_id].process_timer(
#    1111             element.timer_family_id, timer_data)
#    1112     elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1113       input_op_by_transform_id[element.transform_id].process_encoded(
#    1114           element.data)
#    1116 # Finish all operations.
#    1117 for op in self.ops.values():
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\bundle_processor.py:237, in DataInputOperation.process_encoded(self, encoded_windowed_values)
#     233 except Exception as exn:
#     234   raise ValueError(
#     235       "Error decoding input stream with coder " +
#     236       str(self.windowed_coder)) from exn
# --> 237 self.output(decoded_value)
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:570, in apache_beam.runners.worker.operations.Operation.output()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:572, in apache_beam.runners.worker.operations.Operation.output()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:263, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:266, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:1067, in apache_beam.runners.worker.operations.SdfProcessSizedElements.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:1076, in apache_beam.runners.worker.operations.SdfProcessSizedElements.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1467, in apache_beam.runners.common.DoFnRunner.process_with_sized_restriction()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:831, in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:995, in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1621, in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1734, in apache_beam.runners.common._OutputHandler._write_value_to_tag()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:266, in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:953, in apache_beam.runners.worker.operations.DoOperation.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\worker\operations.py:954, in apache_beam.runners.worker.operations.DoOperation.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1437, in apache_beam.runners.common.DoFnRunner.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1547, in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:1435, in apache_beam.runners.common.DoFnRunner.process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\runners\common.py:637, in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# File c:\Program Files\Python311\Lib\site-packages\apache_beam\transforms\core.py:1963, in Map.<locals>.<lambda>(x)
#    1961   wrapper = lambda x, *args, **kwargs: [fn(x, *args, **kwargs)]
#    1962 else:
# -> 1963   wrapper = lambda x: [fn(x)]
#    1965 label = 'Map(%s)' % ptransform.label_from_callable(fn)
#    1967 # TODO. What about callable classes?
#
# Cell In[9], line 6, in cargar_archivo_json(archivo)
#       4 print(archivo)
#       5 x = json.loads(archivo)
# ----> 6 df = pl.DataFrame(x)
#       7 return df
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\dataframe\frame.py:369, in DataFrame.__init__(self, data, schema, schema_overrides, orient, infer_schema_length, nan_to_null)
#     364     self._df = dict_to_pydf(
#     365         {}, schema=schema, schema_overrides=schema_overrides
#     366     )
#     368 elif isinstance(data, dict):
# --> 369     self._df = dict_to_pydf(
#     370         data,
#     371         schema=schema,
#     372         schema_overrides=schema_overrides,
#     373         nan_to_null=nan_to_null,
#     374     )
#     376 elif isinstance(data, (list, tuple, Sequence)):
#     377     self._df = sequence_to_pydf(
#     378         data,
#     379         schema=schema,
#    (...)
#     382         infer_schema_length=infer_schema_length,
#     383     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py:990, in dict_to_pydf(data, schema, schema_overrides, nan_to_null)
#     981     data_series = [
#     982         pl.Series(
#     983             name, [], dtype=schema_overrides.get(name), nan_to_null=nan_to_null
#     984         )._s
#     985         for name in column_names
#     986     ]
#     987 else:
#     988     data_series = [
#     989         s._s
# --> 990         for s in _expand_dict_scalars(
#     991             data, schema_overrides=schema_overrides, nan_to_null=nan_to_null
#     992         ).values()
#     993     ]
#     995 data_series = _handle_columns_arg(data_series, columns=column_names, from_dict=True)
#     996 pydf = PyDataFrame(data_series)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py:890, in _expand_dict_scalars(data, schema_overrides, order, nan_to_null)
#     888 dtype = dtypes.get(name)
#     889 if isinstance(val, dict) and dtype != Struct:
# --> 890     updated_data[name] = pl.DataFrame(val).to_struct(name)
#     892 elif isinstance(val, pl.Series):
#     893     s = val.rename(name) if name != val.name else val
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\dataframe\frame.py:369, in DataFrame.__init__(self, data, schema, schema_overrides, orient, infer_schema_length, nan_to_null)
#     364     self._df = dict_to_pydf(
#     365         {}, schema=schema, schema_overrides=schema_overrides
#     366     )
#     368 elif isinstance(data, dict):
# --> 369     self._df = dict_to_pydf(
#     370         data,
#     371         schema=schema,
#     372         schema_overrides=schema_overrides,
#     373         nan_to_null=nan_to_null,
#     374     )
#     376 elif isinstance(data, (list, tuple, Sequence)):
#     377     self._df = sequence_to_pydf(
#     378         data,
#     379         schema=schema,
#    (...)
#     382         infer_schema_length=infer_schema_length,
#     383     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\polars\utils\_construction.py:996, in dict_to_pydf(data, schema, schema_overrides, nan_to_null)
#     988     data_series = [
#     989         s._s
#     990         for s in _expand_dict_scalars(
#     991             data, schema_overrides=schema_overrides, nan_to_null=nan_to_null
#     992         ).values()
#     993     ]
#     995 data_series = _handle_columns_arg(data_series, columns=column_names, from_dict=True)
# --> 996 pydf = PyDataFrame(data_series)
#     998 if schema_overrides and pydf.dtypes() != list(schema_overrides.values()):
#     999     pydf = _post_apply_columns(
#    1000         pydf, column_names, schema_overrides=schema_overrides
#    1001     )
#
# ShapeError: could not create a new DataFrame: series "Service options" has length 2 while series "Accessibility" has length 1 [while running '[10]: Convertir a DataFrame de Polars']
